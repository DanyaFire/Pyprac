# %% [markdown]
# <a href="https://colab.research.google.com/github/DanyaFire/Pyprac/blob/main/HW14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f"{value:[заполнитель][выравнивание][ширина][.точность][тип]}" #Полная спецификация

# %% [markdown]
# # HomeWork 14
#
#
# **Задача 1**
#
# Оказалось, что в выпускном классе школы города X девять учеников закончили
# школу с отличием. Произошло невероятное совпадение, что у выпускников с красными дипломами на всех три имени, три фамилии и одно отчество:
#
# Имена:
#
# • Александр
#
# • Алекс
#
# • Альберт
#
# Фамилии:
#
# • Вотяк
#
# • Вотяков
#
# • Вотякович
#
# Отчество:
#
# • Романович
#
# Помогите администрации школы не запутаться при выдаче аттестатов, написав
# программу, которая выводит на экран строку в следующем формате для каждого
# выпускника:
#
# "Диплом с отличием вручается Вотякову Александру Романовичу."
#
# Примечание. Не забывайте про склонение имён

# %%
names = ['Александр', 'Алекс', 'Альберт']
surnames = ['Вотяк', 'Вотяков', 'Вотякович']
patronymic = 'Романович'

for surname in surnames:
  for name in names:
    print(f'Диплом с отличием вручается {surname}у {name}у {patronymic}у.')
# Out:
# Диплом с отличием вручается Вотяку Александру Романовичу.
# Диплом с отличием вручается Вотяку Алексу Романовичу.
# Диплом с отличием вручается Вотяку Альберту Романовичу.
# Диплом с отличием вручается Вотякову Александру Романовичу.
# Диплом с отличием вручается Вотякову Алексу Романовичу.
# Диплом с отличием вручается Вотякову Альберту Романовичу.
# Диплом с отличием вручается Вотяковичу Александру Романовичу.
# Диплом с отличием вручается Вотяковичу Алексу Романовичу.
# Диплом с отличием вручается Вотяковичу Альберту Романовичу.

# %% [markdown]
# **Задача 2**
#
# В Москве решили ввести новые экспериментальные номера для автомобилей. Они
# имеют следующий формат, где X соответствует буквам латинского алфавита, а 0
# соответствует десятичным цифрам:
#
# "XXX0000-000"
#
# Напишите программу, которая принимает на вход три значения A, B и C, каждое
# на отдельной строке, а затем выводит соответствующий этим значениям уникальный
# номер. Значение А – первые три буквы номера в виде строки, B – неотрицательное
# число, соответствующее первым четырём цифрам номера и С – неотрицательное
# число, соответствующее последним трём цифрами номера.

# %%
A = input()
B = int(input())
C = int(input())
abc = f'{A}{B:04}-{C:03}'
# print(type(abc))
print(f'{A} {abc:>16}\n{B}\n{C}\n')
# Out:
# ABC
# 24
# 1
# ABC      ABC0024-001
# 24
# 1

# %% [markdown]
# **Задача 3**
#
# Саша в этом году переходит в 4-й класс и впервые столкнулся с языком Python. Он
# узнал, что с помощью f-строк можно не только автоматически выравнивать числа
# по правому краю при сложении их в столбик, но и сразу же получать правильный
# ответ.
#
# Помогите Саше написать программу, которая бы брала на вход два числа
# (A, B < $10^9$
# ) на отдельных строках и выводила в консоль процесс эти два числа,
# где каждый разряд находится под соответствующим разрядом, и результат их сложения.

# %%
A, B = int(input()), int(input())

print(f"{A:>9}\n{B:>9}\n{A+B:>9}")
# Out:
# 10492
# 789
#     10492
#       789
#     11281

# %% [markdown]
# **Задача 4**
#
# Артём 1-го января 2023-го года положил на счёт в банке 100 000 000 рублей под
# r%, который выплачивается в конце каждого месяца. Напишите программу, которая
# считает, сколько денег будет на вкладе через k месяцев. На вход подаются два неотрицательных числа – r и k, где r – процент выплат каждый месяц, а k – количество
# месяцев, которое прошло с открытия вклада.

# %%
r, k = int(input()), int(input())
for n in range(k+1):
  print(f'При k={n} на вкладе {100000000 * ((1+r/100))**n:,.2f} денег.')
# Out:
# 1
# 12
# При k=0 на вкладе 100,000,000.00 денег.
# При k=1 на вкладе 101,000,000.00 денег.
# При k=2 на вкладе 102,010,000.00 денег.
# При k=3 на вкладе 103,030,100.00 денег.
# При k=4 на вкладе 104,060,401.00 денег.
# При k=5 на вкладе 105,101,005.01 денег.
# При k=6 на вкладе 106,152,015.06 денег.
# При k=7 на вкладе 107,213,535.21 денег.
# При k=8 на вкладе 108,285,670.56 денег.
# При k=9 на вкладе 109,368,527.27 денег.
# При k=10 на вкладе 110,462,212.54 денег.
# При k=11 на вкладе 111,566,834.67 денег.
# При k=12 на вкладе 112,682,503.01 денег.

# %% [markdown]
# **Задача 5**
#
# Два друга, Петя и Ваня, решили написать функцию, которая вычисляет всю таблицу умножения от 1 до 100. Чтобы удостовериться, что всё работает правильно, они
# хотят вывести на экран дебаг-строки для всех результатов произведений, в которых
# есть цифра 0.
#
# Помогите Пете и Ване написать программу и проверить её на правильность, добавив дебаг-строки в следующем формате:
#
# "[DEBUG] a=1 b=10 result=10"

# %%
for i in range(1,101):
  for j in range(1,i):
    if '0' in str(i*j):
      print(f'[DEBUG] {i=} {j=} {i*j=}')
# Out:
# [DEBUG] i=5 j=2 i*j=10
# [DEBUG] i=5 j=4 i*j=20
# [DEBUG] i=6 j=5 i*j=30
# [DEBUG] i=8 j=5 i*j=40
# [DEBUG] i=10 j=1 i*j=10
# [DEBUG] i=10 j=2 i*j=20
# [DEBUG] i=10 j=3 i*j=30
# [DEBUG] i=10 j=4 i*j=40
# [DEBUG] i=10 j=5 i*j=50
# [DEBUG] i=10 j=6 i*j=60
# [DEBUG] i=10 j=7 i*j=70
# [DEBUG] i=10 j=8 i*j=80
# [DEBUG] i=10 j=9 i*j=90
# [DEBUG] i=11 j=10 i*j=110
# [DEBUG] i=12 j=5 i*j=60
# [DEBUG] i=12 j=9 i*j=108
# [DEBUG] i=12 j=10 i*j=120
# [DEBUG] i=13 j=8 i*j=104
# [DEBUG] i=13 j=10 i*j=130
# [DEBUG] i=14 j=5 i*j=70
# [DEBUG] i=14 j=10 i*j=140
# [DEBUG] i=15 j=2 i*j=30
# [DEBUG] i=15 j=4 i*j=60
# [DEBUG] i=15 j=6 i*j=90
# [DEBUG] i=15 j=7 i*j=105
# [DEBUG] i=15 j=8 i*j=120
# [DEBUG] i=15 j=10 i*j=150
# [DEBUG] i=15 j=12 i*j=180
# [DEBUG] i=15 j=14 i*j=210
# [DEBUG] i=16 j=5 i*j=80
# [DEBUG] i=16 j=10 i*j=160
# [DEBUG] i=16 j=13 i*j=208
# [DEBUG] i=16 j=15 i*j=240
# [DEBUG] i=17 j=6 i*j=102
# [DEBUG] i=17 j=10 i*j=170
# [DEBUG] i=17 j=12 i*j=204
# [DEBUG] i=18 j=5 i*j=90
# ...

# %% [markdown]
# **Задача 6**
#
# После того, как Петя и Ваня потратили 4 дня, чтобы разобраться с задачками на
# основную теорему арифметики, они решили вычислить создателя этого прототипа
# по IP.
#
# Создатель этих задачек предвидел такое развитие событий и установил защиту от
# вычисления по IP, высылая вместо этого IP серверов из Майнкрафта. Он знает, что
# ни Петя, ни Ваня, не знают, как выглядят IP, поэтому запутать их будет несложно.
# Напишите функцию, которая принимает на вход 4 числа a, b, c и d (0 ≤ a, b, c, d <
# 2
# 8
# ) на одной строке, а затем возвращает IP в следующих форматах, каждое на новой
# строке:
#
# • Восьмибитном двоичном: 01111111.00000000.00000000.00000001
#
# • Двоичном: 1111111.0.0.1
#
# • Восьмиричном: 177.0.0.1
#
# • Десятичном: 127.0.0.1
#
# • Шестнадцатиричном: 7f.0.0.1
#
# Примечание. Используйте метод .format()

# %%
a, b, c, d = list(map(int,input().split()))

formats = ['{:08b}.', '{:b}.', '{:o}.', '{}.', '{:x}.']

for form in formats:
  print((form*4)[:-1].format(a, b, c, d))
# Out:
# 127 0 0 1
# 01111111.00000000.00000000.00000001
# 1111111.0.0.1
# 177.0.0.1
# 127.0.0.1
# 7f.0.0.1
